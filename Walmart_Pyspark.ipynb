# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
spark.stop()

# %%
walmart_df=pd.read_csv("/content/drive/MyDrive/Final Project/datasets/features.csv")

# %%
walmart_df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
walmart_df.isna().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
mean_value1=walmart_df['MarkDown1'].mean()
walmart_df['MarkDown1']=walmart_df['MarkDown1'].fillna(mean_value1)

# %%
walmart_df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price    MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572  7032.371786        NaN
# 1      1  2010-02-12        38.51       2.548  7032.371786        NaN
# 2      1  2010-02-19        39.93       2.514  7032.371786        NaN
# 3      1  2010-02-26        46.63       2.561  7032.371786        NaN
# 4      1  2010-03-05        46.50       2.625  7032.371786        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
mean_value2=walmart_df['MarkDown2'].mean()
walmart_df['MarkDown2']=walmart_df['MarkDown2'].fillna(mean_value2)
mean_value3=walmart_df['MarkDown3'].mean()
walmart_df['MarkDown3']=walmart_df['MarkDown3'].fillna(mean_value3)
mean_value4=walmart_df['MarkDown4'].mean()
walmart_df['MarkDown4']=walmart_df['MarkDown4'].fillna(mean_value4)
mean_value5=walmart_df['MarkDown5'].mean()
walmart_df['MarkDown5']=walmart_df['MarkDown5'].fillna(mean_value5)

# %%
walmart_df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price    MarkDown1    MarkDown2  \
# 0      1  2010-02-05        42.31       2.572  7032.371786  3384.176594
# 1      1  2010-02-12        38.51       2.548  7032.371786  3384.176594
# 2      1  2010-02-19        39.93       2.514  7032.371786  3384.176594
# 3      1  2010-02-26        46.63       2.561  7032.371786  3384.176594
# 4      1  2010-03-05        46.50       2.625  7032.371786  3384.176594
#
#     MarkDown3    MarkDown4    MarkDown5         CPI  Unemployment  IsHoliday
# 0  1760.10018  3292.935886  4132.216422  211.096358         8.106      False
# 1  1760.10018  3292.935886  4132.216422  211.242170         8.106       True
# 2  1760.10018  3292.935886  4132.216422  211.289143         8.106      False
# 3  1760.10018  3292.935886  4132.216422  211.319643         8.106      False
# 4  1760.10018  3292.935886  4132.216422  211.350143         8.106      False

# %%
median1=walmart_df['CPI'].median()
walmart_df['CPI']=walmart_df['CPI'].fillna(median1)
median2=walmart_df['Unemployment'].median()
walmart_df['Unemployment']=walmart_df['Unemployment'].fillna(median2)

# %%
walmart_df.isna().sum()
# Out:
# Store           0
# Date            0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# IsHoliday       0
# dtype: int64

# %%
walmart_df.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    8190.000000    8190.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    6498.764307    5250.998063
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    4842.382500    1410.940000
# 50%      23.000000    60.710000     3.513000    7032.371786    3384.176594
# 75%      34.000000    73.880000     3.743000    7032.371786    3384.176594
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    8190.000000   8190.000000    8190.000000  8190.000000   8190.000000
# mean     1760.100180   3292.935886    4132.216422   173.196752      7.825334
# std      7489.128873   4417.022169    9202.128149    38.384486      1.808971
# min      -179.260000      0.220000    -185.170000   126.064000      3.684000
# 25%        54.017500   1737.530000    2753.105000   132.653774      6.833000
# 50%      1760.100180   3292.935886    4132.216422   182.764003      7.806000
# 75%      1760.100180   3292.935886    4132.216422   212.766994      8.519000
# max    149483.310000  67474.850000  771448.100000   228.976456     14.313000

# %%
walmart_df.shape
# Out:
# (8190, 12)

# %%
walmart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     8190 non-null   float64
#  5   MarkDown2     8190 non-null   float64
#  6   MarkDown3     8190 non-null   float64
#  7   MarkDown4     8190 non-null   float64
#  8   MarkDown5     8190 non-null   float64
#  9   CPI           8190 non-null   float64
#  10  Unemployment  8190 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
walmart_df.plot(kind='density',subplots=True,sharex=False,figsize=(8,9))
plt.show()

# %%
walmart_df.plot(kind='box',subplots=True,sharex=False,sharey=False,figsize=(20,10))
plt.show()

# %%
import numpy as np
Walmart_corr=walmart_df.corr()

# %%
fd = walmart_df.to_csv('/content/drive/MyDrive/Final Project/Out1/walmart.csv')

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.8/dist-packages (3.3.2)
# Requirement already satisfied: py4j==0.10.9.5 in /usr/local/lib/python3.8/dist-packages (from pyspark) (0.10.9.5)

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext


spark = SparkSession \
.builder \
.appName("Walmart") \
.config("spark.some.config.option", "some-value") \
.getOrCreate()

# %%
feature_df = spark.read.csv("/content/drive/MyDrive/Final Project/Out1/walmart.csv",header=True);
train_df = spark.read.csv("/content/drive/MyDrive/Final Project/datasets/train.csv",header=True);
stores_df = spark.read.csv("/content/drive/MyDrive/Final Project/datasets/stores.csv",header=True);

# %%
feature_df.take(5)
# Out:
# [Row(_c0='0', Store='1', Date='2010-02-05', Temperature='42.31', Fuel_Price='2.572', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.0963582', Unemployment='8.106', IsHoliday='False'),
#  Row(_c0='1', Store='1', Date='2010-02-12', Temperature='38.51', Fuel_Price='2.548', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.2421698', Unemployment='8.106', IsHoliday='True'),
#  Row(_c0='2', Store='1', Date='2010-02-19', Temperature='39.93', Fuel_Price='2.514', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.2891429', Unemployment='8.106', IsHoliday='False'),
#  Row(_c0='3', Store='1', Date='2010-02-26', Temperature='46.63', Fuel_Price='2.561', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.3196429', Unemployment='8.106', IsHoliday='False'),
#  Row(_c0='4', Store='1', Date='2010-03-05', Temperature='46.5', Fuel_Price='2.625', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.3501429', Unemployment='8.106', IsHoliday='False')]

# %%
train_df=train_df.join(stores_df, ['Store'], how='full')

# %%
merge_df=feature_df.join(train_df, ['Store','Date'], how='inner')

# %%
merge_df.take(1)
# Out:
# [Row(Store='1', Date='2010-02-05', _c0='0', Temperature='42.31', Fuel_Price='2.572', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.0963582', Unemployment='8.106', IsHoliday='False', Dept='1', Weekly_Sales='24924.5', IsHoliday='FALSE', Type='A', Size='151315')]

# %%
merge_df.count()
# Out:
# 421570

# %%
train, test = merge_df.randomSplit([0.8, 0.2])

# %%
train.head()
# Out:
# Row(Store='1', Date='2010-02-05', _c0='0', Temperature='42.31', Fuel_Price='2.572', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.0963582', Unemployment='8.106', IsHoliday='False', Dept='1', Weekly_Sales='24924.5', IsHoliday='FALSE', Type='A', Size='151315')

# %%
from pyspark.sql.functions import mean as _mean
train.groupBy('Store').agg(_mean('Weekly_Sales').alias('Weekly_Sales')).show()
# Out:
# +-----+------------------+
# |Store|      Weekly_Sales|
# +-----+------------------+
# |    7| 8441.070941935475|
# |   15| 9018.626903055438|
# |   11|19191.221702524537|
# |   29|8136.8837955532235|
# |    3|  6449.49455088157|
# |    8|13013.222708860796|
# |   22|15334.880703808565|
# |   28|18778.004907338753|
# |   16| 7883.256148167684|
# |    5| 5071.448963414631|
# |   18|15630.269516742703|
# |   27|24900.631417226577|
# |   17|12970.482349936121|
# |   26|14654.296535723388|
# |    6|21850.727249724936|
# |   19|20677.886273398988|
# |   23|19690.742194249022|
# |   25|10274.243023752675|
# |   24|18983.403117088525|
# |    9| 8809.769873737363|
# +-----+------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import mean as _mean
train.groupBy('Dept').agg(_mean('Weekly_Sales').alias('Weekly_Sales')).show()
# Out:
# +----+------------------+
# |Dept|      Weekly_Sales|
# +----+------------------+
# |  51|21.537533512064304|
# |   7| 24342.53005701927|
# |  54|107.59968691960756|
# |  11|14491.612556621893|
# |  29| 5651.671964119292|
# |  42| 5200.346746170254|
# |  87|13306.893430027476|
# |   3|11804.398678913441|
# |  30| 4130.478609738884|
# |  34|15549.189255770087|
# |  59|  677.787654474064|
# |   8|30086.696310264397|
# |  22| 10752.50027481264|
# |  28| 618.6844523182825|
# |  85| 2267.318851844136|
# |  16|14241.991269223254|
# |  35|2893.4423205068024|
# |  52|1920.9893150414523|
# |  71|5702.2245585457795|
# |  98| 6845.821465590488|
# +----+------------------+
# only showing top 20 rows

# %%
merge_df.count()
# Out:
# 421570

# %%
merge_df.take(5)
# Out:
# [Row(Store='1', Date='2010-02-05', _c0='0', Temperature='42.31', Fuel_Price='2.572', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.0963582', Unemployment='8.106', IsHoliday='False', Dept='1', Weekly_Sales='24924.5', IsHoliday='FALSE', Type='A', Size='151315'),
#  Row(Store='1', Date='2010-02-12', _c0='1', Temperature='38.51', Fuel_Price='2.548', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.2421698', Unemployment='8.106', IsHoliday='True', Dept='1', Weekly_Sales='46039.49', IsHoliday='TRUE', Type='A', Size='151315'),
#  Row(Store='1', Date='2010-02-19', _c0='2', Temperature='39.93', Fuel_Price='2.514', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.2891429', Unemployment='8.106', IsHoliday='False', Dept='1', Weekly_Sales='41595.55', IsHoliday='FALSE', Type='A', Size='151315'),
#  Row(Store='1', Date='2010-02-26', _c0='3', Temperature='46.63', Fuel_Price='2.561', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.3196429', Unemployment='8.106', IsHoliday='False', Dept='1', Weekly_Sales='19403.54', IsHoliday='FALSE', Type='A', Size='151315'),
#  Row(Store='1', Date='2010-03-05', _c0='4', Temperature='46.5', Fuel_Price='2.625', MarkDown1='7032.371785714286', MarkDown2='3384.1765936323177', MarkDown3='1760.1001799058954', MarkDown4='3292.9358862586605', MarkDown5='4132.216422222222', CPI='211.3501429', Unemployment='8.106', IsHoliday='False', Dept='1', Weekly_Sales='21827.9', IsHoliday='FALSE', Type='A', Size='151315')]

# %%
merge_df=merge_df.toPandas()

# %%
merge_df.drop(["_c0"], axis = 1, inplace = True)

# %%
fd1 = merge_df.to_csv('/content/drive/MyDrive/Final Project/Out1/merge_df.csv')

# %%
import pandas as pd
final_df1=pd.read_csv("/content/drive/MyDrive/Final Project/Out1/merge_df.csv")

# %%
final_df1.corr()
# Out:
#               Unnamed: 0     Store  Temperature  Fuel_Price  MarkDown1  \
# Unnamed: 0      1.000000  0.999198    -0.053526    0.068573  -0.069204
# Store           0.999198  1.000000    -0.050097    0.065290  -0.071492
# Temperature    -0.053526 -0.050097     1.000000    0.143859  -0.023452
# Fuel_Price      0.068573  0.065290     0.143859    1.000000   0.033128
# MarkDown1      -0.069204 -0.071492    -0.023452    0.033128   1.000000
# MarkDown2      -0.016912 -0.017179    -0.162464   -0.071678   0.022222
# MarkDown3      -0.017024 -0.017360    -0.051196   -0.048856  -0.107828
# MarkDown4      -0.005678 -0.006447    -0.035113   -0.010492   0.786658
# MarkDown5      -0.015843 -0.015800    -0.010817   -0.015979   0.161146
# CPI            -0.218301 -0.211088     0.182112   -0.164210  -0.032790
# Unemployment    0.213702  0.208552     0.096730   -0.033853   0.023242
# IsHoliday      -0.000530 -0.000548    -0.155949   -0.078281  -0.021931
# Dept            0.045990  0.024004     0.004437    0.003572  -0.001359
# Weekly_Sales   -0.082372 -0.085195    -0.002312   -0.000120   0.052356
# IsHoliday.1    -0.000530 -0.000548    -0.155949   -0.078281  -0.021931
# Size           -0.175516 -0.182881    -0.058313    0.003361   0.206330
#
#               MarkDown2  MarkDown3  MarkDown4  MarkDown5       CPI  \
# Unnamed: 0    -0.016912  -0.017024  -0.005678  -0.015843 -0.218301
# Store         -0.017179  -0.017360  -0.006447  -0.015800 -0.211088
# Temperature   -0.162464  -0.051196  -0.035113  -0.010817  0.182112
# Fuel_Price    -0.071678  -0.048856  -0.010492  -0.015979 -0.164210
# MarkDown1      0.022222  -0.107828   0.786658   0.161146 -0.032790
# MarkDown2      1.000000  -0.048317  -0.006708  -0.007515 -0.020997
# MarkDown3     -0.048317   1.000000  -0.070576  -0.027629 -0.015543
# MarkDown4     -0.006708  -0.070576   1.000000   0.106745 -0.027887
# MarkDown5     -0.007515  -0.027629   0.106745   1.000000  0.041906
# CPI           -0.020997  -0.015543  -0.027887   0.041906  1.000000
# Unemployment   0.010714   0.012332   0.010433  -0.017077 -0.299953
# IsHoliday      0.198192   0.262991   0.000007  -0.032199 -0.001944
# Dept           0.000142   0.000913   0.002378   0.000395 -0.007477
# Weekly_Sales   0.012994   0.035373   0.027356   0.055712 -0.020921
# IsHoliday.1    0.198192   0.262991   0.000007  -0.032199 -0.001944
# Size           0.051437   0.025537   0.086367   0.182239 -0.003314
#
#               Unemployment  IsHoliday      Dept  Weekly_Sales  IsHoliday.1  \
# Unnamed: 0        0.213702  -0.000530  0.045990     -0.082372    -0.000530
# Store             0.208552  -0.000548  0.024004     -0.085195    -0.000548
# Temperature       0.096730  -0.155949  0.004437     -0.002312    -0.155949
# Fuel_Price       -0.033853  -0.078281  0.003572     -0.000120    -0.078281
# MarkDown1         0.023242  -0.021931 -0.001359      0.052356    -0.021931
# MarkDown2         0.010714   0.198192  0.000142      0.012994     0.198192
# MarkDown3         0.012332   0.262991  0.000913      0.035373     0.262991
# MarkDown4         0.010433   0.000007  0.002378      0.027356     0.000007
# MarkDown5        -0.017077  -0.032199  0.000395      0.055712    -0.032199
# CPI              -0.299953  -0.001944 -0.007477     -0.020921    -0.001944
# Unemployment      1.000000   0.010460  0.007837     -0.025864     0.010460
# IsHoliday         0.010460   1.000000  0.000916      0.012774     1.000000
# Dept              0.007837   0.000916  1.000000      0.148032     0.000916
# Weekly_Sales     -0.025864   0.012774  0.148032      1.000000     0.012774
# IsHoliday.1       0.010460   1.000000  0.000916      0.012774     1.000000
# Size             -0.068238   0.000593 -0.002966      0.243828     0.000593
#
#                   Size
# Unnamed: 0   -0.175516
# Store        -0.182881
# Temperature  -0.058313
# Fuel_Price    0.003361
# MarkDown1     0.206330
# MarkDown2     0.051437
# MarkDown3     0.025537
# MarkDown4     0.086367
# MarkDown5     0.182239
# CPI          -0.003314
# Unemployment -0.068238
# IsHoliday     0.000593
# Dept         -0.002966
# Weekly_Sales  0.243828
# IsHoliday.1   0.000593
# Size          1.000000

# %%
spark.stop()

# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext
sc= SparkContext()
sqlContext = SQLContext(sc)
# Out:
# /usr/local/lib/python3.8/dist-packages/pyspark/sql/context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %%
Walmart_df = sqlContext.read.format('com.databricks.spark.csv').options(header='true', inferschema='true').load('/content/drive/MyDrive/Final Project/Out1/merge_df.csv')

# %%
Walmart_df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Store: integer (nullable = true)
#  |-- Date: timestamp (nullable = true)
#  |-- Temperature: double (nullable = true)
#  |-- Fuel_Price: double (nullable = true)
#  |-- MarkDown1: double (nullable = true)
#  |-- MarkDown2: double (nullable = true)
#  |-- MarkDown3: double (nullable = true)
#  |-- MarkDown4: double (nullable = true)
#  |-- MarkDown5: double (nullable = true)
#  |-- CPI: double (nullable = true)
#  |-- Unemployment: double (nullable = true)
#  |-- IsHoliday12: boolean (nullable = true)
#  |-- Dept: integer (nullable = true)
#  |-- Weekly_Sales: double (nullable = true)
#  |-- IsHoliday15: boolean (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- Size: integer (nullable = true)

# %%
Walmart_df.columns
# Out:
# ['_c0',
#  'Store',
#  'Date',
#  'Temperature',
#  'Fuel_Price',
#  'MarkDown1',
#  'MarkDown2',
#  'MarkDown3',
#  'MarkDown4',
#  'MarkDown5',
#  'CPI',
#  'Unemployment',
#  'IsHoliday12',
#  'Dept',
#  'Weekly_Sales',
#  'IsHoliday15',
#  'Type',
#  'Size']

# %%
Walmart_df.columns
# Out:
# ['_c0',
#  'Store',
#  'Date',
#  'Temperature',
#  'Fuel_Price',
#  'MarkDown1',
#  'MarkDown2',
#  'MarkDown3',
#  'MarkDown4',
#  'MarkDown5',
#  'CPI',
#  'Unemployment',
#  'IsHoliday12',
#  'Dept',
#  'Weekly_Sales',
#  'IsHoliday15',
#  'Type',
#  'Size']

# %%
Walmart_df=Walmart_df.drop('Date','Type')

# %%
Walmart_df.head()
# Out:
# Row(_c0=0, Store=1, Temperature=42.31, Fuel_Price=2.572, MarkDown1=7032.371785714286, MarkDown2=3384.1765936323177, MarkDown3=1760.1001799058954, MarkDown4=3292.9358862586605, MarkDown5=4132.216422222222, CPI=211.0963582, Unemployment=8.106, IsHoliday12=False, Dept=1, Weekly_Sales=24924.5, IsHoliday15=False, Type='A', Size=151315)

# %%
from pyspark.ml.feature import VectorAssembler

vectorAssembler = VectorAssembler(inputCols = ['_c0',
 'Store',
 'Temperature',
 'Fuel_Price',
 'MarkDown1',
 'MarkDown2',
 'MarkDown3',
 'MarkDown4',
 'MarkDown5',
 'CPI',
 'Unemployment',
 'IsHoliday12',
 'Dept',
 'Weekly_Sales',
 'IsHoliday15',
 'Size'], outputCol = 'features')
vfinal_df = vectorAssembler.transform(Walmart_df)
vfinal_df = vfinal_df.select(['features', 'Weekly_Sales'])
vfinal_df.show(3)
# Out:
# +--------------------+------------+
# |            features|Weekly_Sales|
# +--------------------+------------+
# |[0.0,1.0,42.31,2....|     24924.5|
# |[1.0,1.0,38.51,2....|    46039.49|
# |[2.0,1.0,39.93,2....|    41595.55|
# +--------------------+------------+
# only showing top 3 rows

# %%
splits = vfinal_df.randomSplit([0.8, 0.2])
train_df = splits[0]
test_df = splits[1]

# %%
from pyspark.ml.regression import LinearRegression

lr = LinearRegression(featuresCol = 'features', labelCol='Weekly_Sales', maxIter=10, regParam=0.3, elasticNetParam=0.8)
lr_model = lr.fit(train_df)

# %%
trainingSummary = lr_model.summary
rmse=trainingSummary.rootMeanSquaredError
rmse=rmse*1000
print("RMSE: %f" % rmse)
print("r2: %f" % trainingSummary.r2)
# Out:
# RMSE: 3377.570218
# r2: 1.000000

# %%
train_df.describe().show()
# Out:
# +-------+------------------+
# |summary|      Weekly_Sales|
# +-------+------------------+
# |  count|            337404|
# |   mean|15958.676141006456|
# | stddev|22649.645260226243|
# |    min|           -3924.0|
# |    max|         693099.36|
# +-------+------------------+

# %%
lr_predictions = lr_model.transform(test_df)
lr_predictions.select("prediction","Weekly_Sales","features").show(5)

from pyspark.ml.evaluation import RegressionEvaluator
lr_evaluator = RegressionEvaluator(predictionCol="prediction", \
                 labelCol="Weekly_Sales",metricName="r2")
print("R Squared (R2) on test data = %g" % lr_evaluator.evaluate(lr_predictions))
# Out:
# +------------------+------------+--------------------+
# |        prediction|Weekly_Sales|            features|
# +------------------+------------+--------------------+
# |19404.197670841037|    19403.54|[3.0,1.0,46.63,2....|
# |   42960.991441382|    42960.91|[9.0,1.0,65.86,2....|
# |16217.013037330176|    16216.27|[19.0,1.0,84.11,2...|
# |15361.216932224634|    15360.45|[24.0,1.0,83.36,2...|
# |18195.433611629138|    18194.74|[31.0,1.0,78.69,2...|
# +------------------+------------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 1

# %%
print("numIterations: %d" % trainingSummary.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary.objectiveHistory))
trainingSummary.residuals.show()
# Out:
# +--------------------+
# |           residuals|
# +--------------------+
# | -0.5215723839210114|
# |0.008129500107315835|
# |-0.10263910916546592|
# | -0.5967242223669018|
# | -0.6160735388657486|
# | -0.5902282569586532|
# |-0.48962943706283113|
# | 0.27813720370613737|
# | -0.7173548583959928|
# | -0.7541314076916024|
# | -0.7443306743662106|
# |  -0.723292809096165|
# | -0.6854592634335859|
# | -0.7868313501439843|
# | -0.7640614933989127|
# | -0.7120078314328566|
# | -0.7324744197940163|
# | -0.7412772432617203|
# | -0.7427046140201128|
# | -0.7098365365236532|
# +--------------------+
# only showing top 20 rows

# %%
predictions = lr_model.transform(test_df)
predictions.select("prediction","Weekly_Sales","features").show()
# Out:
# +------------------+------------+--------------------+
# |        prediction|Weekly_Sales|            features|
# +------------------+------------+--------------------+
# |19404.197670841037|    19403.54|[3.0,1.0,46.63,2....|
# |   42960.991441382|    42960.91|[9.0,1.0,65.86,2....|
# |16217.013037330176|    16216.27|[19.0,1.0,84.11,2...|
# |15361.216932224634|    15360.45|[24.0,1.0,83.36,2...|
# |18195.433611629138|    18194.74|[31.0,1.0,78.69,2...|
# |19354.894345627417|    19354.23|[32.0,1.0,82.11,2...|
# |18123.214479371305|    18122.52|[33.0,1.0,80.94,2...|
# | 26978.80971205747|    26978.34|[36.0,1.0,67.18,2...|
# |25543.545189819535|    25543.04|[37.0,1.0,69.86,2...|
# | 55930.97894867667|    55931.23|[46.0,1.0,52.33,2...|
# | 37887.35862301875|    37887.17|[53.0,1.0,36.39,3...|
# |28762.766723662233|    28762.37|[62.0,1.0,71.27,3...|
# |41512.464592597054|    41512.39|[64.0,1.0,72.03,3...|
# |15137.513615256035|    15136.78|[67.0,1.0,67.63,3...|
# |15742.320589209588|     15741.6|[68.0,1.0,77.72,3...|
# |   15884.241254802|    15883.52|[70.0,1.0,83.13,3...|
# |15683.535837156229|    15682.81|[72.0,1.0,83.58,3...|
# |15296.274901376946|    15295.55|[78.0,1.0,91.65,3...|
# |17747.340655291508|    17746.68|[83.0,1.0,76.0,3....|
# |18338.318070663678|    18337.68|[86.0,1.0,79.69,3...|
# +------------------+------------+--------------------+
# only showing top 20 rows

# %%
predictions.take(5)
# Out:
# [Row(features=DenseVector([3.0, 1.0, 46.63, 2.561, 7032.3718, 3384.1766, 1760.1002, 3292.9359, 4132.2164, 211.3196, 8.106, 0.0, 1.0, 19403.54, 0.0, 151315.0]), Weekly_Sales=19403.54, prediction=19404.197670841037),
#  Row(features=DenseVector([9.0, 1.0, 65.86, 2.77, 7032.3718, 3384.1766, 1760.1002, 3292.9359, 4132.2164, 210.6229, 7.808, 0.0, 1.0, 42960.91, 0.0, 151315.0]), Weekly_Sales=42960.91, prediction=42960.991441382),
#  Row(features=DenseVector([19.0, 1.0, 84.11, 2.637, 7032.3718, 3384.1766, 1760.1002, 3292.9359, 4132.2164, 211.4538, 7.808, 0.0, 1.0, 16216.27, 0.0, 151315.0]), Weekly_Sales=16216.27, prediction=16217.013037330176),
#  Row(features=DenseVector([24.0, 1.0, 83.36, 2.608, 7032.3718, 3384.1766, 1760.1002, 3292.9359, 4132.2164, 211.2351, 7.787, 0.0, 1.0, 15360.45, 0.0, 151315.0]), Weekly_Sales=15360.45, prediction=15361.216932224634),
#  Row(features=DenseVector([31.0, 1.0, 78.69, 2.565, 7032.3718, 3384.1766, 1760.1002, 3292.9359, 4132.2164, 211.4952, 7.787, 1.0, 1.0, 18194.74, 1.0, 151315.0]), Weekly_Sales=18194.74, prediction=18195.433611629138)]

# %%
from pyspark.ml.regression import GBTRegressor
gbt = GBTRegressor(featuresCol = 'features', labelCol = 'Weekly_Sales', maxIter=10)
gbt_model = gbt.fit(train_df)
gbt_predictions = gbt_model.transform(test_df)
gbt_predictions.select('prediction', 'Weekly_Sales', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="Weekly_Sales", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# +------------------+------------+--------------------+
# |        prediction|Weekly_Sales|            features|
# +------------------+------------+--------------------+
# |18520.893553523645|    19403.54|[3.0,1.0,46.63,2....|
# | 39582.65440677233|    42960.91|[9.0,1.0,65.86,2....|
# | 16406.17269143403|    16216.27|[19.0,1.0,84.11,2...|
# | 14476.03915120994|    15360.45|[24.0,1.0,83.36,2...|
# |18520.893553523645|    18194.74|[31.0,1.0,78.69,2...|
# +------------------+------------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 4770.11

# %%
predictions=predictions.toPandas()

# %%
pred=predictions.to_csv('/content/drive/MyDrive/Final Project/Out1/prediction.csv')

# %%
import pandas as pd
p1=pd.read_csv("/content/drive/MyDrive/Final Project/Out1/prediction.csv")

# %%
from pyspark.ml.regression import GBTRegressor
gbt = GBTRegressor(featuresCol = 'features', labelCol = 'Weekly_Sales', maxIter=10)
gbt_model = gbt.fit(train_df)
gbt_predictions = gbt_model.transform(test_df)
gbt_predictions.select('prediction', 'Weekly_Sales', 'features').show(5)
gbt_evaluator = RegressionEvaluator(
    labelCol="Weekly_Sales", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# +------------------+------------+--------------------+
# |        prediction|Weekly_Sales|            features|
# +------------------+------------+--------------------+
# |18520.893553523645|    19403.54|[3.0,1.0,46.63,2....|
# | 39582.65440677233|    42960.91|[9.0,1.0,65.86,2....|
# | 16406.17269143403|    16216.27|[19.0,1.0,84.11,2...|
# | 14476.03915120994|    15360.45|[24.0,1.0,83.36,2...|
# |18520.893553523645|    18194.74|[31.0,1.0,78.69,2...|
# +------------------+------------+--------------------+
# only showing top 5 rows
#
# Root Mean Squared Error (RMSE) on test data = 4770.11

# %%
p1.head()
# Out:
#    Unnamed: 0                                           features  \
# 0           0  [3.0,1.0,46.63,2.561,7032.371785714286,3384.17...
# 1           1  [9.0,1.0,65.86,2.77,7032.371785714286,3384.176...
# 2           2  [19.0,1.0,84.11,2.637,7032.371785714286,3384.1...
# 3           3  [24.0,1.0,83.36,2.608,7032.371785714286,3384.1...
# 4           4  [31.0,1.0,78.69,2.565,7032.371785714286,3384.1...
#
#    Weekly_Sales    prediction
# 0      19403.54  19404.197671
# 1      42960.91  42960.991441
# 2      16216.27  16217.013037
# 3      15360.45  15361.216932
# 4      18194.74  18195.433612

# %%
plt.plot( p1['prediction'], color='g')
plt.plot( p1['Weekly_Sales'], color='orange')
plt.xlabel('Predictions')
plt.ylabel('weekly Sales')
plt.title('Weekly Sales vs Predictions')
plt.show()

# %%
import seaborn as sns

# %%
sns.scatterplot(data=p1, x="prediction", y="Weekly_Sales")

# %%
from pyspark.ml.regression import DecisionTreeRegressor

dt = DecisionTreeRegressor(featuresCol ='features', labelCol = 'Weekly_Sales')
dt_model = dt.fit(train_df)
dt_predictions = dt_model.transform(test_df)
dt_predictions.select('prediction', 'Weekly_Sales', 'features').show(5)
dt_evaluator = RegressionEvaluator(
    labelCol="Weekly_Sales", predictionCol="prediction", metricName="rmse")
rmse = dt_evaluator.evaluate(dt_predictions)
# Out:
# +------------------+------------+--------------------+
# |        prediction|Weekly_Sales|            features|
# +------------------+------------+--------------------+
# | 20704.31029638961|    19403.54|[3.0,1.0,46.63,2....|
# | 46542.68635619243|    42960.91|[9.0,1.0,65.86,2....|
# |15952.257010950261|    16216.27|[19.0,1.0,84.11,2...|
# |15952.257010950261|    15360.45|[24.0,1.0,83.36,2...|
# |18073.817254124282|    18194.74|[31.0,1.0,78.69,2...|
# +------------------+------------+--------------------+
# only showing top 5 rows

# %%
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5c6b4d5d9db0> in <module>
# ----> 1 spark.stop()
#
# NameError: name 'spark' is not defined
